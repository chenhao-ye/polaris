# %%
import pandas as pd
from tqdm import tqdm
import re

# %%
clv = True
NUM_THREAD = 5
STATUS = {0:"commit", 2:"abort"}

def get_thd(txn):
    return txn % NUM_THREAD

def rm_txn(row, place, txn):
    thread = get_thd(txn)
    members = locktable[row][place]
    found = False
    for i, step in enumerate(members):
        if step[0] == txn:
            found = True
            break
    if not found:
        print("not found: {}".format(line))
        raise
    locktable[row][place] = members[:i] + members[i+1:]
    return thread, members[i]

def get_schedule(start, end, thread):
    return schedule.loc[start:end+1, thread][schedule.loc[start:end+1, thread].notnull()]

def find_locktable_with_txn(txn):
    for row in locktable:
        if txn in [item[0] for place in ['owners', 'waiters', 'retired'] for item in locktable[row][place] ]:
            print(row)
            print(locktable[row])
            
def find_locktable_with_row(row):
    print(locktable[row])
    
def get_p(txn):
    if txn in priority:
        p = priority[txn]
    else:
        p = -1
    return p

# %%
match_bracket = re.compile(r"[\[](.*)[\]](.*)")
match_thread = re.compile(r"thread-(\d*)")
match_txn = re.compile(r"txn-(\d*)\s*[\(]*(\d*)[\)]*")
match_rowclv = re.compile(r"row_clv-(\d*)")
match_row = re.compile(r"row-(\d*)")
match_type = re.compile(r"[\(]type (\d)[\)]")

def extract_type(content):
    t = match_type.search(content).group(1)
    if (t == 0):
        return "SH"
    else:
        return "EX"
    
def init_row(row):
    if row not in locktable:
        locktable[row] = {}
        locktable[row]['owners'] = []
        locktable[row]['waiters'] = []
        locktable[row]['retired'] = []
        
def add_to(row, place, item):
    init_row(row)
    locktable[row][place].append(item)

def parse(line): 
    if "[" not in line:
        return
    # init variables
    thread = -1
    txn = -1
    p = -1
    row = ""
    # match [*] *
    matched = match_bracket.search(line)
    header = matched.group(1)
    content = matched.group(2)
    # match thread
    matched = match_thread.search(header)
    if (matched):
        thread = int(matched.group(1))
    # match txn
    matched = match_txn.search(header)
    if (matched):
        txn = int(matched.group(1))
        if (matched.group(2)):
            p = int(matched.group(2))
            priority[txn] = p
    # match row
    matched = match_rowclv.search(header)
    if (matched):
        row = matched.group(1)
    matched = match_row.search(header)
    if (matched):
        row = matched.group(1)
    # process content
    if row != "":
        if "add to waiters" in content:
            add_to(row, "waiters", (txn, ts, extract_type(content)))
        elif "move to owners" in content:
            thread, item = rm_txn(row, "waiters", txn)
            add_to(row, "owners", item)
        elif "rm from owners" in content:
            thread, item = rm_txn(row, "owners", txn)
        elif "move to retired" in content:
            add_to(row, "retired", (txn, ts, extract_type(content)))
        elif "wound txn" in content:
            schedule.loc[ts, get_thd(txn)] = content + " on %s"%row
            wounded = int(content.split()[2])
            schedule.loc[ts, get_thd(wounded)] = "wounded by %d on %s"%(txn, row) 
    elif txn != -1:
        if thread == -1:
            if "set ts" in line:
                schedule.loc[ts, get_thd(txn)] = "txn %d "%txn + content
                priority[txn] = p
            elif "set to abort" in line:
                schedule.loc[ts, get_thd(txn)] = "txn %d "%txn + content
            elif "increment barrier":
                barriers[txn] += 1
                schedule.loc[ts, get_thd(txn)] = "txn %d "%txn + content
            elif "decrement barrier":
                barriers[txn] -= 1
                schedule.loc[ts, get_thd(txn)] = "txn %d "%txn + content
        else:
            barriers[txn] = 0
            priority[txn] = 0
            schedule.loc[ts, thread] = "txn %d "%txn + content
    elif thread != -1:
        if "finish" in content:
            schedule.loc[ts, thread] = content
            txn = int(content.split()[-2])
            print("\ntxn %d aborted, should have no entry in locktable"%txn)
            find_locktable_with_txn(txn)
            if "(aborted)" in line:
                barriers[txn] = 0

# %%
output = open('debug.out')

# %%
locktable = {} # row_id: { owners: {}, waiters: {}, (opt) retired: {}}
barriers = {}
priority = {}
schedule = pd.DataFrame()
ts = 0

# %%
for line in tqdm(output):
    try:
        parse(line.strip())
        ts += 1
    except:
        print(line)
        raise
# Out:
# 244it [00:00, 2029.43it/s]
# txn 4 aborted, should have no entry in locktable
# 4638309604021045
# {'owners': [], 'waiters': [], 'retired': [(4, 18, 'EX'), (1, 32, 'EX'), (0, 47, 'EX')]}
# 4638309604023475
# {'owners': [], 'waiters': [(4, 23, 'EX'), (0, 49, 'EX')], 'retired': [(1, 37, 'EX')]}
#
# txn 0 aborted, should have no entry in locktable
# 4638309604021045
# {'owners': [], 'waiters': [], 'retired': [(4, 18, 'EX'), (1, 32, 'EX'), (0, 47, 'EX'), (2, 92, 'EX'), (9, 120, 'EX'), (3, 137, 'EX')]}
# 4638309604023475
# {'owners': [], 'waiters': [(4, 23, 'EX')], 'retired': [(1, 37, 'EX'), (0, 72, 'EX'), (2, 104, 'EX'), (9, 135, 'EX')]}
# 4638309604024473
# {'owners': [], 'waiters': [], 'retired': [(1, 41, 'EX'), (0, 84, 'EX')]}
# 4638309604024736
# {'owners': [], 'waiters': [], 'retired': [(0, 109, 'EX')]}
#
# txn 2 aborted, should have no entry in locktable
# 4638309604021045
# {'owners': [], 'waiters': [], 'retired': [(4, 18, 'EX'), (1, 32, 'EX'), (0, 47, 'EX'), (2, 92, 'EX'), (9, 120, 'EX'), (3, 137, 'EX')]}
# 4638309604023475
# {'owners': [], 'waiters': [(4, 23, 'EX')], 'retired': [(1, 37, 'EX'), (0, 72, 'EX'), (2, 104, 'EX'), (9, 135, 'EX'), (3, 152, 'EX')]}
#
# txn 3 aborted, should have no entry in locktable
# 4638309604021045
# {'owners': [], 'waiters': [], 'retired': [(4, 18, 'EX'), (1, 32, 'EX'), (0, 47, 'EX'), (2, 92, 'EX'), (9, 120, 'EX'), (3, 137, 'EX'), (5, 191, 'EX')]}
# 4638309604023475
# {'owners': [], 'waiters': [(4, 23, 'EX')], 'retired': [(1, 37, 'EX'), (0, 72, 'EX'), (2, 104, 'EX'), (9, 135, 'EX'), (3, 152, 'EX'), (5, 197, 'EX')]}
# 4638309604024473
# {'owners': [], 'waiters': [(3, 164, 'EX'), (5, 198, 'EX')], 'retired': [(1, 41, 'EX'), (0, 84, 'EX'), (9, 151, 'EX')]}

# %%
schedule
# Out:
#                                           4  \
# 8                      txn 4  start running
# 10                                      NaN
# 12                                      NaN
# 13                                      NaN
# 14                                      NaN
# 19                                      NaN
# 20                      txn 4  set to abort
# 21         wounded by 1 on 4638309604021045
# 22                          txn 4  set ts 2
# 26    txn 4  change ts to 4 for aborted txn
# 27                 txn 4  is set to aborted
# 33                                      NaN
# 46                                      NaN
# 50                   finish txn 4 (aborted)
# 52                     txn 9  start running
# 53                                      NaN
# 81                                      NaN
# 83                                      NaN
# 99                                      NaN
# 100     wound txn 0 (6) on 4638309604021045
# 103                                     NaN
# 105                                     NaN
# 106                                     NaN
# 108    wound txn 2 (10) on 4638309604021045
# 110                                     NaN
# 112                                     NaN
# 119           txn 9  increment barrier to 1
# 122                                     NaN
# 123                                     NaN
# 134           txn 9  increment barrier to 2
# 136                                     NaN
# 147           txn 9  increment barrier to 3
# 148                                     NaN
# 149                                     NaN
# 155                                     NaN
# 156                                     NaN
# 157                                     NaN
# 158                                     NaN
# 160                                     NaN
# 168                                     NaN
# 169                                     NaN
# 189                                     NaN
# 196                                     NaN
# 202                                     NaN
# 205                                     NaN
# 209                                     NaN
# 211                                     NaN
# 216                                     NaN
# 217                                     NaN
# 220                                     NaN
# 226                                     NaN
# 228                                     NaN
# 232                                     NaN
# 234                                     NaN
# 237  txn 9  change ts to 17 for aborted txn
# 238                txn 9  is set to aborted
#
#                                         1  \
# 8                                     NaN
# 10                   txn 1  start running
# 12                                    NaN
# 13                                    NaN
# 14                                    NaN
# 19                        txn 1  set ts 3
# 20                                    NaN
# 21    wound txn 4 (0) on 4638309604021045
# 22                                    NaN
# 26                                    NaN
# 27                                    NaN
# 33                                    NaN
# 46                                    NaN
# 50                                    NaN
# 52                                    NaN
# 53                                    NaN
# 81                                    NaN
# 83                                    NaN
# 99                                    NaN
# 100                                   NaN
# 103                                   NaN
# 105                                   NaN
# 106                                   NaN
# 108                                   NaN
# 110                                   NaN
# 112                                   NaN
# 119                                   NaN
# 122                                   NaN
# 123                                   NaN
# 134                                   NaN
# 136                                   NaN
# 147                                   NaN
# 148                                   NaN
# 149                                   NaN
# 155                                   NaN
# 156                                   NaN
# 157                                   NaN
# 158                                   NaN
# 160                                   NaN
# 168                                   NaN
# 169                                   NaN
# 189                                   NaN
# 196                                   NaN
# 202                                   NaN
# 205                                   NaN
# 209                                   NaN
# 211                                   NaN
# 216                                   NaN
# 217                                   NaN
# 220                    txn 1  # bariers 0
# 226                                   NaN
# 228             txn 1  is set to commited
# 232      wounded by 8 on 4638309604021045
# 234      wounded by 7 on 4638309604023475
# 237                                   NaN
# 238                                   NaN
#
#                                           0  \
# 8                                       NaN
# 10                                      NaN
# 12                     txn 0  start running
# 13                                      NaN
# 14                                      NaN
# 19                                      NaN
# 20                                      NaN
# 21                                      NaN
# 22                                      NaN
# 26                                      NaN
# 27                                      NaN
# 33                          txn 0  set ts 6
# 46            txn 0  increment barrier to 1
# 50                                      NaN
# 52                                      NaN
# 53                                      NaN
# 81                                      NaN
# 83            txn 0  increment barrier to 2
# 99                      txn 0  set to abort
# 100        wounded by 9 on 4638309604021045
# 103                                     NaN
# 105                                     NaN
# 106                                     NaN
# 108                                     NaN
# 110                                     NaN
# 112  txn 0  change ts to 11 for aborted txn
# 119                                     NaN
# 122                                     NaN
# 123                txn 0  is set to aborted
# 134                                     NaN
# 136                                     NaN
# 147                                     NaN
# 148                  finish txn 0 (aborted)
# 149                                     NaN
# 155                    txn 5  start running
# 156                                     NaN
# 157                                     NaN
# 158    wound txn 3 (14) on 4638309604021045
# 160                                     NaN
# 168                                     NaN
# 169                                     NaN
# 189           txn 5  increment barrier to 1
# 196           txn 5  increment barrier to 2
# 202                                     NaN
# 205                     txn 5  set to abort
# 209        wounded by 7 on 4638309604021045
# 211                                     NaN
# 216  txn 5  change ts to 16 for aborted txn
# 217                txn 5  is set to aborted
# 220                                     NaN
# 226                                     NaN
# 228                                     NaN
# 232                                     NaN
# 234                                     NaN
# 237                                     NaN
# 238                                     NaN
#
#                                           2  \
# 8                                       NaN
# 10                                      NaN
# 12                                      NaN
# 13                     txn 2  start running
# 14                                      NaN
# 19                                      NaN
# 20                                      NaN
# 21                                      NaN
# 22                                      NaN
# 26                                      NaN
# 27                                      NaN
# 33                                      NaN
# 46                                      NaN
# 50                                      NaN
# 52                                      NaN
# 53                          txn 2  set ts 9
# 81            txn 2  increment barrier to 1
# 83                                      NaN
# 99                                      NaN
# 100                                     NaN
# 103           txn 2  increment barrier to 2
# 105                     txn 2  set to abort
# 106  txn 2  change ts to 10 for aborted txn
# 108        wounded by 9 on 4638309604021045
# 110                txn 2  is set to aborted
# 112                                     NaN
# 119                                     NaN
# 122                                     NaN
# 123                                     NaN
# 134                                     NaN
# 136                                     NaN
# 147                                     NaN
# 148                                     NaN
# 149                                     NaN
# 155                                     NaN
# 156                  finish txn 2 (aborted)
# 157                                     NaN
# 158                                     NaN
# 160                    txn 7  start running
# 168                                     NaN
# 169                                     NaN
# 189                                     NaN
# 196                                     NaN
# 202                                     NaN
# 205                                     NaN
# 209    wound txn 5 (11) on 4638309604021045
# 211                                     NaN
# 216                                     NaN
# 217                                     NaN
# 220                                     NaN
# 226           txn 7  increment barrier to 1
# 228                                     NaN
# 232                                     NaN
# 234     wound txn 1 (0) on 4638309604023475
# 237                                     NaN
# 238                                     NaN
#
#                                           3
# 8                                       NaN
# 10                                      NaN
# 12                                      NaN
# 13                                      NaN
# 14                     txn 3  start running
# 19                                      NaN
# 20                                      NaN
# 21                                      NaN
# 22                                      NaN
# 26                                      NaN
# 27                                      NaN
# 33                                      NaN
# 46                                      NaN
# 50                                      NaN
# 52                                      NaN
# 53                                      NaN
# 81                                      NaN
# 83                                      NaN
# 99                                      NaN
# 100                                     NaN
# 103                                     NaN
# 105                                     NaN
# 106                                     NaN
# 108                                     NaN
# 110                                     NaN
# 112                                     NaN
# 119                                     NaN
# 122                        txn 3  set ts 14
# 123                                     NaN
# 134                                     NaN
# 136           txn 3  increment barrier to 1
# 147                                     NaN
# 148                                     NaN
# 149           txn 3  increment barrier to 2
# 155                                     NaN
# 156                                     NaN
# 157                     txn 3  set to abort
# 158        wounded by 5 on 4638309604021045
# 160                                     NaN
# 168  txn 3  change ts to 15 for aborted txn
# 169                txn 3  is set to aborted
# 189                                     NaN
# 196                                     NaN
# 202                  finish txn 3 (aborted)
# 205                                     NaN
# 209                                     NaN
# 211                    txn 8  start running
# 216                                     NaN
# 217                                     NaN
# 220                                     NaN
# 226                                     NaN
# 228                                     NaN
# 232     wound txn 1 (0) on 4638309604021045
# 234                                     NaN
# 237                                     NaN
# 238                                     NaN

# %%
for b in barriers:
    if barriers[b] > 0:
        print("{} = {} at thread {}".format(b, barriers[b], int(b)%NUM_THREAD))
# Out:
# 1 = 2 at thread 1
# 9 = 4 at thread 4
# 5 = 3 at thread 0
# 7 = 1 at thread 2
